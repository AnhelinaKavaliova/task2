# %% [markdown]
# <a href="https://colab.research.google.com/github/AnhelinaKavaliova/task2/blob/main/assignment_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Датасет собран из базы данных переписи 1994 года и содержит данные о доходах.
# ### Информация о данных:
# * age: continuous.
# * workclass: Private, Self-emp-not-inc, Self-emp-inc, Federal-gov, Local-gov, State-gov, Without-pay, Never-worked.
# * fnlwgt: continuous.
# * education: Bachelors, Some-college, 11th, HS-grad, Prof-school, Assoc-acdm, Assoc-voc, 9th, 7th-8th, 12th, * Masters, 1st-4th, 10th, Doctorate, 5th-6th, Preschool.
# * education-num: continuous.
# * marital-status: Married-civ-spouse, Divorced, Never-married, Separated, Widowed, Married-spouse-absent, Married-AF-spouse.
# * occupation: Tech-support, Craft-repair, Other-service, Sales, Exec-managerial, Prof-specialty, Handlers-cleaners, Machine-op-inspct, Adm-clerical, Farming-fishing, Transport-moving, Priv-house-serv, Protective-serv, Armed-Forces.
# * relationship: Wife, Own-child, Husband, Not-in-family, Other-relative, Unmarried.
# * race: White, Asian-Pac-Islander, Amer-Indian-Eskimo, Other, Black.
# * sex: Female, Male.
# * capital-gain: continuous.
# * capital-loss: continuous.
# * hours-per-week: continuous.
# * native-country: United-States, Cambodia, England, Puerto-Rico, Canada, Germany, Outlying-US(Guam-USVI-etc), India, Japan, Greece, South, China, Cuba, Iran, Honduras, Philippines, Italy, Poland, Jamaica, Vietnam, Mexico, Portugal, Ireland, France, Dominican-Republic, Laos, Ecuador, Taiwan, Haiti, Columbia, Hungary, Guatemala, Nicaragua, Scotland, Thailand, Yugoslavia, El-Salvador, Trinadad&Tobago, Peru, Hong, Holand-Netherlands.
# * salary: >50K,<=50K
#
# ## Проведите анализ данных при помощи Pandas выполнив поставленные задачи.
# ####

# %%
import pandas as pd

# %%
# загружаем датасет
data = pd.read_csv("./data/adult.data.csv")
data.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0          2174             0              40  United-States  <=50K
# ...

# %% [markdown]
# **1. Посчитайте, сколько мужчин и женщин (признак *sex*) представлено в этом датасете**

# %%
data.groupby('sex').size()
# Out:
# sex
# Female    10771
# Male      21790
# dtype: int64

# %%
data['sex'].value_counts()
# Out:
# sex
# Male      21790
# Female    10771
# Name: count, dtype: int64

# %% [markdown]
# **2. Каков средний возраст мужчин (признак *age*) по всему датасету?**

# %%
data[data['sex'] == 'Male']['age'].mean()
# Out:
# 39.43354749885268

# %% [markdown]
# **3. Какова доля граждан Соединенных Штатов (признак *native-country*)?**

# %%
us_citizens = data[data['native-country'] == 'United-States'].shape[0] / data.shape[0]
us_citizens *= 100
print(f'{us_citizens:.2f}%')
# Out:
# 89.59%

# %% [markdown]
# **4-5. Рассчитайте среднее значение и среднеквадратичное отклонение возраста тех, кто получает более 50K в год (признак *salary*) и тех, кто получает менее 50K в год**

# %%
mean_age_more = data[data['salary'] == '>50K']['age'].mean()
std_age_more = data[data['salary'] == '>50K']['age'].std()

mean_age_less = data[data['salary'] == '<=50K']['age'].mean()
std_age_less = data[data['salary'] == '<=50K']['age'].std()

print("Mean age of those who earn more than 50k: ", mean_age_more)
print("Std age of those who earn more than 50k: ", std_age_more)
print("Mean age of those who earn less than 50k: ", mean_age_less)
print("Std age of those who earn less than 50k: ", std_age_less)
# Out:
# Mean age of those who earn more than 50k:  44.24984058155847
# Std age of those who earn more than 50k:  10.519027719851826
# Mean age of those who earn less than 50k:  36.78373786407767
# Std age of those who earn less than 50k:  14.02008849082488

# %% [markdown]
# **6. Правда ли, что люди, которые получают больше 50k, имеют минимум высшее образование? (признак *education – Bachelors, Prof-school, Assoc-acdm, Assoc-voc, Masters* или *Doctorate*)**

# %%
high_income = data[data['salary'] == '>50K']
high_education_all = high_income['education'].isin(['Bachelors', 'Prof-school', 'Assoc-acdm', 'Assoc-voc', 'Masters', 'Doctorate']).all()
high_education_all
# Out:
# False

# %% [markdown]
# **7. Выведите статистику возраста для каждой расы (признак *race*) и каждого пола. Используйте *groupby* и *describe*. Найдите таким образом максимальный возраст мужчин расы *Asian-Pac-Islander*.**

# %%
age_stat = data.groupby(['race','sex'])['age'].describe()
max_male_asian_pac_islander_age = age_stat.loc[('Asian-Pac-Islander', 'Male'), 'max']
print("Max male Asian-Pac-Islander age: ", max_male_asian_pac_islander_age)
print(age_stat)
# Out:
# Max male Asian-Pac-Islander age:  90.0
#                              count       mean        std   min   25%   50%  \
# race               sex
# Amer-Indian-Eskimo Female    119.0  37.117647  13.114991  17.0  27.0  36.0
#                    Male      192.0  37.208333  12.049563  17.0  28.0  35.0
# Asian-Pac-Islander Female    346.0  35.089595  12.300845  17.0  25.0  33.0
#                    Male      693.0  39.073593  12.883944  18.0  29.0  37.0
# Black              Female   1555.0  37.854019  12.637197  17.0  28.0  37.0
#                    Male     1569.0  37.682600  12.882612  17.0  27.0  36.0
# Other              Female    109.0  31.678899  11.631599  17.0  23.0  29.0
#                    Male      162.0  34.654321  11.355531  17.0  26.0  32.0
# White              Female   8642.0  36.811618  14.329093  17.0  25.0  35.0
#                    Male    19174.0  39.652498  13.436029  17.0  29.0  38.0
#
#                              75%   max
# race               sex
# ...

# %% [markdown]
# **8. Среди кого больше доля зарабатывающих много (>50K): среди женатых или холостых мужчин (признак *marital-status*)? Женатыми считаем тех, у кого *marital-status* начинается с *Married* (Married-civ-spouse, Married-spouse-absent или Married-AF-spouse), остальных считаем холостыми.**

# %%
high_income_men = data[(data['salary'] == '>50K') & (data['sex'] == 'Male')]
married_men_mask = high_income_men['marital-status'].str.startswith('Married')

married_men_frac = high_income_men[married_men_mask].shape[0] / high_income_men.shape[0]
single_men_frac = high_income_men[~married_men_mask].shape[0] / high_income_men.shape[0]

if married_men_frac > single_men_frac:
  print("More men with a salary >50k among married people")
else: print("More men with a salary >50k among single people")
# Out:
# More men with a salary >50k among married people

# %% [markdown]
# **9. Какое максимальное число часов человек работает в неделю (признак *hours-per-week*)? Сколько людей работают такое количество часов и каков среди них процент зарабатывающих много?**

# %%
max_work_hours = data['hours-per-week'].max()
max_work_hours_people = data[data['hours-per-week'] == max_work_hours]
high_income_max_work = max_work_hours_people[max_work_hours_people['salary'] == '>50K'].shape[0]
percent_high_income_max_work_hours_people = (high_income_max_work / max_work_hours_people.shape[0]) *100

print("Max number of hours a person works per week: ", max_work_hours)
print("People work max number of hours per week: ", max_work_hours_people.shape[0])
print(f"Percent people work max number of hours per week: {percent_high_income_max_work_hours_people:.2f}%")
# Out:
# Max number of hours a person works per week:  99
# People work max number of hours per week:  85
# Percent people work max number of hours per week: 29.41%

# %% [markdown]
# **10. Посчитайте среднее время работы (*hours-per-week*) зарабатывающих мало и много (*salary*) для каждой страны (*native-country*).**

# %%
high_income = data[data['salary'] == '>50K']
low_income = data[data['salary'] == '<=50K']

high_income_hours = high_income.groupby('native-country')['hours-per-week'].mean()
low_income_hours = low_income.groupby('native-country')['hours-per-week'].mean()

print("Mean number of hours work for high inxome by country:", high_income_hours)
print("Mean number of hours work for low income by country:", low_income_hours)
# Out:
# Mean number of hours work for high inxome by country: native-country
# ?                     45.547945
# Cambodia              40.000000
# Canada                45.641026
# China                 38.900000
# Columbia              50.000000
# Cuba                  42.440000
# Dominican-Republic    47.000000
# Ecuador               48.750000
# El-Salvador           45.000000
# England               44.533333
# France                50.750000
# Germany               44.977273
# Greece                50.625000
# Guatemala             36.666667
# Haiti                 42.750000
# Honduras              60.000000
# Hong                  45.000000
# Hungary               50.000000
# India                 46.475000
# Iran                  47.500000
# Ireland               48.000000
# Italy                 45.400000
# Jamaica               41.100000
# Japan                 47.958333
# Laos                  40.000000
# Mexico                46.575758
# Nicaragua             37.500000
# ...

# %%
income_work_hours = data.groupby(['native-country', 'salary'])['hours-per-week'].mean().reset_index()

high_income_hours = income_work_hours[income_work_hours['salary'] == '>50K']
low_income_hours = income_work_hours[income_work_hours['salary'] == '<=50K']

print("Mean number of hours work for high inxome by country:", high_income_hours)
print("Mean number of hours work for low income by country:", low_income_hours)
# Out:
# Mean number of hours work for high inxome by country:         native-country salary  hours-per-week
# 1                    ?   >50K       45.547945
# 3             Cambodia   >50K       40.000000
# 5               Canada   >50K       45.641026
# 7                China   >50K       38.900000
# 9             Columbia   >50K       50.000000
# 11                Cuba   >50K       42.440000
# 13  Dominican-Republic   >50K       47.000000
# 15             Ecuador   >50K       48.750000
# 17         El-Salvador   >50K       45.000000
# 19             England   >50K       44.533333
# 21              France   >50K       50.750000
# 23             Germany   >50K       44.977273
# 25              Greece   >50K       50.625000
# 27           Guatemala   >50K       36.666667
# 29               Haiti   >50K       42.750000
# 32            Honduras   >50K       60.000000
# 34                Hong   >50K       45.000000
# 36             Hungary   >50K       50.000000
# ...

# %% [markdown]
# **11.Сгруппируйте людей по возрастным группам *young*, *adult*, *retiree*, где:**
# * *young* соответствует 16-35 лет
# * *adult* - 35-70 лет
# * *retiree* - 70-100 лет
#
# **Проставьте название соответсвтуещей группы для каждого человека в новой колонке AgeGroup**

# %%
def get_age_group(age):
    if 16 <= age < 35:
        return 'young'
    elif 35 <= age < 70:
        return 'adult'
    elif 70 <= age <= 100:
        return 'retiree'
    else:
        return 0

data['AgeGroup'] = data['age'].apply(get_age_group)
data.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary AgeGroup
# 0          2174             0              40  United-States  <=50K    adult
# ...

# %%
bins = [0, 16, 35, 70, 100]
labels = [0, 'young', 'adult', 'retiree']

data['AgeGroup'] = pd.cut(data['age'], bins=bins, labels=labels, right=False)
data.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary AgeGroup
# 0          2174             0              40  United-States  <=50K    adult
# ...

# %% [markdown]
# **12-13. Определите количество зарабатывающих >50K в каждой из возрастных групп (колонка AgeGroup), а также выведите название возрастной группы, в которой чаще зарабатывают больше 50К (>50K)**

# %%
high_income = data[data['salary'] == '>50K']

high_income_agegroups = high_income.groupby('AgeGroup').size()
total_agegroups = data.groupby('AgeGroup').size()
high_income_agegroups_frac = high_income_agegroups / total_agegroups

print("Number of earners >50K in each age group:\n",high_income_agegroups )
print("Age group where people most often earn more than 50K:", high_income_agegroups_frac.idxmax())
# Out:
# Number of earners >50K in each age group:
#  AgeGroup
# 0             0
# young      1488
# adult      6240
# retiree     113
# dtype: int64
# Age group where people most often earn more than 50K: adult
# <ipython-input-16-dacdef4c58c2>:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   high_income_agegroups = high_income.groupby('AgeGroup').size()
# <ipython-input-16-dacdef4c58c2>:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   total_agegroups = data.groupby('AgeGroup').size()

# %% [markdown]
# **14. Сгруппируйте людей по типу занятости (колонка occupation) и определите количество людей в каждой группе. После чего напишите функциюю фильтрации filter_func, которая будет возвращать только те группы, в которых средний возраст (колонка age) не больше 40 и в которых все работники отрабатывают более 5 часов в неделю (колонка hours-per-week)**

# %%
def filter_func(group):
  return group['age'].mean() <= 40 and (group['hours-per-week'] > 5).all()

filtered_data = data.groupby('occupation').filter(filter_func)
occupations = filtered_data['occupation'].unique()

print("Number of people in each group: ", data.groupby('occupation').size())
print("Valid groups: ", occupations)
# Out:
# Number of people in each group:  occupation
# ?                    1843
# Adm-clerical         3770
# Armed-Forces            9
# Craft-repair         4099
# Exec-managerial      4066
# Farming-fishing       994
# Handlers-cleaners    1370
# Machine-op-inspct    2002
# Other-service        3295
# Priv-house-serv       149
# Prof-specialty       4140
# Protective-serv       649
# Sales                3650
# Tech-support          928
# Transport-moving     1597
# dtype: int64
# Valid groups:  ['Armed-Forces']

# %%
grouped_occupation = data.groupby('occupation')
occupation_size = grouped_occupation.size()

def filter_func(groups):
  valid_groups = []

  for name_group, group in groups:
    if group['age'].mean() <= 40 and (group['hours-per-week'] > 5).all():
      valid_groups.append(name_group)

  return valid_groups

print("Number of people in each group: \n", occupation_size)
print("Valid groups: ", filter_func(grouped_occupation))
# Out:
# Number of people in each group:
#  occupation
# ?                    1843
# Adm-clerical         3770
# Armed-Forces            9
# Craft-repair         4099
# Exec-managerial      4066
# Farming-fishing       994
# Handlers-cleaners    1370
# Machine-op-inspct    2002
# Other-service        3295
# Priv-house-serv       149
# Prof-specialty       4140
# Protective-serv       649
# Sales                3650
# Tech-support          928
# Transport-moving     1597
# dtype: int64
# Valid groups:  ['Armed-Forces']
